# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
class Cage(nx.Graph):
  def constCage(self, order, girth):
    if order == 3:
      if girth == 5:
        self.cage = nx.petersen_graph()
      if girth == 6:
        self.cage = nx.generators.small.heawood_graph()
      if girth == 7:
        _cage = nx.cycle_graph(24)   # Cyclic Graph having 24 vertices
        eList = []
        for i in range(8):
          edge = (3*i,(3*i+7)%24)   # Edge on Class 1 type of Vertices
          eList.append(edge)
        for i in range(4):
          edge = (3*i+2,(3*i+14)%24)   # Edge on Class 2 type of Vertices
          eList.append(edge)
        _cage.add_edges_from(eList)
        self.cage = _cage
      if girth == 8:
        _cage = nx.cycle_graph(30)   # Cyclic Graph having 30 vertices 
        eList = []
        for i in range(5):
          edge = (6*i+3,(6*i+10)%30)   # Edge on Class 1 type of Vertices
          eList.append(edge)
          edge = (6*i+5,(6*i+14)%30)   # Edge on Class 2 type of Vertices
          eList.append(edge)
          edge = (6*i,(6*i+13)%30)   # Edge on Class 3 type of Vertices
          eList.append(edge)
        _cage.add_edges_from(eList)
        self.cage = _cage
      if girth == 9:
        _cage = nx.cycle_graph(58)
        eList = [( 0, 8), ( 1, 26), ( 2, 41), ( 3, 12), ( 4, 46), ( 5, 54), ( 6, 33), ( 7, 19), ( 9, 38), ( 10, 51), ( 11, 30), ( 13, 21), ( 14, 35), ( 15, 53), ( 16, 40), ( 17, 47), ( 18, 28), ( 20, 43), ( 22, 56), ( 23, 39), ( 24, 32), ( 25, 52), ( 27, 36), ( 29, 55), ( 31, 44), ( 34, 49), ( 37, 45), ( 42, 50), ( 48, 57)]
        _cage.add_edges_from(eList)
        self.cage = _cage
        _cages = [_cage]
        eList = [[( 0, 8), ( 1, 26), ( 2, 41), ( 3, 12), ( 4, 46), ( 5, 54), ( 6, 33), ( 7, 19), ( 9, 38), ( 10, 51), ( 11, 30), 
                  ( 13, 21), ( 14, 35), ( 15, 53), ( 16, 40), ( 17, 47), ( 18, 28), ( 20, 43), ( 22, 56), ( 23, 39), ( 24, 32), 
                  ( 25, 52), ( 27, 36), ( 29, 55), ( 31, 44), ( 34, 49), ( 37, 45), ( 42, 50), ( 48, 57)],
                 [( 0, 8), ( 1, 51), ( 2, 29), ( 3, 38), ( 4, 47), ( 5, 33), ( 6, 14), ( 7, 43), ( 9, 26), ( 10, 48), ( 11, 31), 
                  ( 12, 37), ( 13, 55), ( 15, 50), ( 16, 25), ( 17, 41), ( 18, 57), ( 19, 35), ( 20, 28), ( 21, 49), ( 22, 39), 
                  ( 23, 32), ( 24, 45), ( 27, 54), ( 30, 42), ( 34, 52), ( 36, 44), ( 40, 53), ( 46, 56)],
                 [( 0, 8), ( 1, 15), ( 2, 42), ( 3, 49), ( 4, 37), ( 5, 54), ( 6, 45), ( 7, 26), ( 9, 21), ( 10, 31), ( 11, 47), 
                  ( 12, 36), ( 13, 27), ( 14, 53), ( 16, 32), ( 17, 38), ( 18, 46), ( 19, 28), ( 20, 51), ( 22, 43), ( 23, 55), 
                  ( 12, 45), ( 3, 52), ( 14, 22), ( 15, 38), ( 17, 33), ( 19, 54), ( 20, 29), ( 23, 42), ( 24, 48), ( 25, 56), 
                  ( 28, 36), ( 30, 46), ( 31, 40), ( 32, 51), ( 4, 57), ( 35, 43), ( 37, 49), ( 39, 55)],
                 [( 0, 8), ( 1, 49), ( 2, 37), ( 3, 30), ( 4, 22), ( 5, 14), ( 6, 44), ( 7, 27), ( 9, 32), ( 10, 20), ( 11, 38), 
                  ( 12, 54), ( 3, 48), ( 15, 34), ( 16, 40), ( 17, 57), ( 18, 29), ( 19, 46), ( 21, 51), ( 23, 56), ( 24, 33), 
                  ( 25, 47), ( 26, 39), ( 28, 53), ( 31, 42), ( 5, 52), ( 36, 45), ( 41, 50), ( 43, 55)],
                 [( 0, 8), ( 1, 25), ( 2, 34), ( 3, 20), ( 4, 40), ( 5, 15), ( 6, 30), ( 7, 51), ( 9, 42), ( 10, 18), ( 11, 33), 
                  ( 12, 49), ( 3, 26), ( 14, 44), ( 16, 56), ( 17, 37), ( 19, 28), ( 21, 50), ( 22, 43), ( 23, 31), ( 24, 38), 
                  ( 27, 53), ( 29, 46), ( 32, 55), ( 35, 45), ( 6, 52), ( 39, 48), ( 41, 54), ( 47, 57)],
                 [( 0, 8), ( 1, 34), ( 2, 48), ( 3, 22), ( 4, 12), ( 5, 27), ( 6, 41), ( 7, 18), ( 9, 45), ( 10, 38), ( 11, 32), 
                  ( 13, 51), ( 4, 57), ( 15, 24), ( 16, 47), ( 17, 36), ( 19, 52), ( 20, 31), ( 21, 44), ( 23, 39), ( 25, 33), 
                  ( 26, 53), ( 28, 37), ( 29, 49), ( 30, 56), ( 5, 43), ( 40, 55), ( 42, 50), ( 46, 54)]]
        for list in eList:
          _cage = nx.cycle_graph(58)
          _cage.add_edges_from(list)
          _cages.append(_cage)
        self.cages = _cages
      if girth == 10:
        _cage = nx.cycle_graph(70)
        eList = [( 0, 9), ( 1, 52), ( 2, 41), ( 3, 22), ( 4, 57), ( 5, 16), ( 6, 27), ( 7, 64), ( 8, 47), ( 10, 31), ( 11, 56), 
                 ( 12, 25), ( 13, 40), ( 14, 61), ( 15, 34), ( 17, 44), ( 18, 69), ( 19, 38), ( 20, 63), ( 21, 32), ( 23, 46), 
                 ( 24, 66), ( 26, 51), ( 28, 37), ( 29, 60), ( 30, 43), ( 33, 50), ( 35, 66), ( 36, 55), ( 39, 48), ( 42, 65), 
                 ( 45, 54), ( 49, 58), ( 53, 62), ( 59, 68)]
        _cage.add_edges_from(eList)
        self.cage = _cage
        _cages = [_cage]
        _cage = nx.cycle_graph(70)
        lcf = [-35,-27,27,-23,15,-15,-9,-35,23,-27,27,9,15,-15]
        lcf_order = 5
        i = 0
        eList = []
        for order in range(lcf_order):
          for j in lcf:
            eList.append((i,(i+j)%70))
            i = i + 1
        _cage.add_edges_from(eList)
        _cages.append(_cage)
        _cage = nx.cycle_graph(70)
        lcf = [9, 25, 31, -17, 17, 33, 9, -29, -15, -9, 9, 25, -25, 29, 17, -9, 9, -27, 35, -9, 9, -17, 21, 27, -29, -9, -25, 
               13, 19, -9, -33, -17, 19, -31, 27, 11, -25, 29, -33, 13, -13, 21, -29, -21, 25, 9, -11, -19, 29, 9, -27, -19, 
               -13, -35, -9, 9, 17, 25, -9, 9, 27, -27, -21, 15, -9, 29, -29, 33, -9, -25]
        eList = []
        for i in range(70):
          eList.append((i,(i+lcf[i])%70))
        _cage.add_edges_from(eList)
        _cages.append(_cage)
        self.cages = _cages

      if girth == 11:
        _cage = nx.cycle_graph(112)
        lcf = [44, 26, -47, -15, 35, -39, 11, -27, 38, -37, 43, 14, 28, 51, -29, -16, 41, -11, -26, 15, 22, -51, -35, 36, 52, 
               -14, -33, -26, -46, 52, 26, 16, 43, 33, -15, 17, -53, 23, -42, -35, -28, 30, -22, 45, -44, 16, -38, -16, 50, -55, 
               20, 28, -17, -43, 47, 34, -26, -41, 11, -36, -23, -16, 41, 17, -51, 26, -33, 47, 17, -11, -20, -30, 21, 29, 36, 
               -43, -52, 10, 39, -28, -17, -52, 51, 26, 37, -17, 10, -10, -45, -34, 17, -26, 27, -21, 46, 53, -10, 29, -50, 35, 
               15, -47, -29, -41, 26, 33, 55, -17, 42, -26, -36, 16]
        eList = []
        for i in range(112):
          eList.append((i,(i+lcf[i])%112))
        _cage.add_edges_from(eList)
        self.cage = _cage
      
      if girth == 12:
        _cage = nx.cycle_graph(126)
        lcf = [17,27,-13,-59,-35,35,-11,13,-53,53,-27,21,57,11,-21,-57.59,-17]
        lcf_order = 7
        i = 0
        eList = []
        for order in range(lcf_order):
          for j in lcf:
            eList.append((i,(i+j)%126))
            i = i + 1
        _cage.add_edges_from(eList)
        self.cage = _cage


  def __init__(self, order, girth):
    self.order = order
    self.girth = girth
    self.constCage(order, girth)

# %%
x = Cage(3,5).cage
nx.draw_shell(x, nlist=[range(5, 10), range(5)], node_size=20)

# %%
x = Cage(3,6).cage
nx.draw_shell(x, node_size=20)

# %%
x = Cage(3,7).cage
nx.draw_shell(x, node_size=20)

# %%
x = Cage(3,8).cage
nx.draw_shell(x, node_size=20)

# %%
x = Cage(3,9).cage
nx.draw_shell(x, node_size=20)

# %%
x = Cage(3,9).cages[0]
nx.draw_shell(x, node_size=20)

# %%
x = Cage(3,9).cages[1]
nx.draw_shell(x, node_size=20)

# %%
x = Cage(3,10).cage
nx.draw_shell(x, node_size = 20)

# %%
x = Cage(3,10).cages
nx.draw_shell(x[1], node_size=20)

# %%
x = Cage(3,10).cages[2]
nx.draw_shell(x, node_size = 20)

# %%
x = Cage(3,11).cage
nx.draw_shell(x, node_size = 20)

# %%
x = Cage(3,12).cage
nx.draw_shell(x, node_size = 20)
